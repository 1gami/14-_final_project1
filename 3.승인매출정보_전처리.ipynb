# %%
import os
import pandas as pd
import numpy as np

# %%
df7 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201807_train_승인매출정보.parquet")
df8 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201808_train_승인매출정보.parquet")
df9 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201809_train_승인매출정보.parquet")
df10 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201810_train_승인매출정보.parquet")
df11 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201811_train_승인매출정보.parquet")
df12 = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\train\3.승인매출정보\201812_train_승인매출정보.parquet")

# %%
dfs = [df7, df8, df9, df10, df11, df12]
merged_df = pd.concat(dfs, ignore_index=True)

# %%
for col, dtype in merged_df.dtypes.items():
    if dtype == 'float64':
        merged_df[col] = merged_df[col].astype('float32')
    elif dtype == 'int64':
        merged_df[col] = merged_df[col].astype('int32')

# %%
merged_df.to_parquet("3.승인정보_all_month.parquet")

# %%
df = pd.read_parquet(r"C:\Users\rtc32\OneDrive\바탕 화면\final_project\project\3.승인정보_all_month.parquet")

# %%
# 고유값이 1개인 컬럼 드랍
"""['이용건수_부분무이자_B0M', '이용금액_부분무이자_B0M', '여유_여행이용금액', '납부_렌탈료이용금액', '납부_유선방송이용금액', '납부_건강연금이용금액',
  '할부건수_부분_3M_R12M', '할부건수_부분_6M_R12M', '할부건수_부분_14M_R12M', '할부금액_부분_3M_R12M', 'RP건수_유선방송_B0M', 'RP건수_건강_B0M', 
 'RP후경과월_유선방송', 'RP후경과월_건강', '증감_RP건수_유선방송_전월', '증감_RP건수_건강_전월', '이용개월수_당사페이_R6M', '이용금액_당사페이_R6M', 
'이용금액_당사기타_R6M', '이용건수_당사페이_R6M', '이용건수_당사기타_R6M', '이용금액_당사페이_R3M', '이용금액_당사기타_R3M', '이용건수_당사페이_R3M', 
'이용건수_당사기타_R3M', '이용금액_당사페이_B0M', '이용금액_당사기타_B0M', '이용건수_당사페이_B0M', '이용건수_당사기타_B0M', '승인거절건수_입력오류_B0M', '승인거절건수_기타_B0M']
"""
unique_cols = [col for col in df.columns if df[col].nunique() == 1]
df = df.drop(columns=unique_cols)
print(f"드랍된 컬럼: {unique_cols}")
# Out:
# 드랍된 컬럼: ['이용건수_부분무이자_B0M', '이용금액_부분무이자_B0M', '여유_여행이용금액', '납부_렌탈료이용금액', '납부_유선방송이용금액', '납부_건강연금이용금액', '할부건수_부분_3M_R12M', '할부건수_부분_6M_R12M', '할부건수_부분_14M_R12M', '할부금액_부분_3M_R12M', 'RP건수_유선방송_B0M', 'RP건수_건강_B0M', 'RP후경과월_유선방송', 'RP후경과월_건강', '증감_RP건수_유선방송_전월', '증감_RP건수_건강_전월', '이용개월수_당사페이_R6M', '이용금액_당사페이_R6M', '이용금액_당사기타_R6M', '이용건수_당사페이_R6M', '이용건수_당사기타_R6M', '이용금액_당사페이_R3M', '이용금액_당사기타_R3M', '이용건수_당사페이_R3M', '이용건수_당사기타_R3M', '이용금액_당사페이_B0M', '이용금액_당사기타_B0M', '이용건수_당사페이_B0M', '이용건수_당사기타_B0M', '승인거절건수_입력오류_B0M', '승인거절건수_기타_B0M']

# %%
print(f"컬럼 총 개수: {df.shape[1]}")
# Out:
# 컬럼 총 개수: 375

# %%
print(f"드랍된 컬럼 개수: {len(unique_cols)}")
# Out:
# 드랍된 컬럼 개수: 31

# %%
# 범주형 데이터 중 결측치가 있는 컬럼을 찾아 '기타'로 채우기
cat_cols = df.select_dtypes(include=['object', 'category']).columns
for col in cat_cols:
    if df[col].isnull().any():
        df[col] = df[col].fillna('기타')
        print(f"{col} 컬럼의 결측치를 '기타'로 채움")
# Out:
# _1순위업종 컬럼의 결측치를 '기타'로 채움
# _2순위업종 컬럼의 결측치를 '기타'로 채움
# _3순위업종 컬럼의 결측치를 '기타'로 채움
# _1순위쇼핑업종 컬럼의 결측치를 '기타'로 채움
# _2순위쇼핑업종 컬럼의 결측치를 '기타'로 채움
# _3순위쇼핑업종 컬럼의 결측치를 '기타'로 채움
# _1순위교통업종 컬럼의 결측치를 '기타'로 채움
# _2순위교통업종 컬럼의 결측치를 '기타'로 채움
# _3순위교통업종 컬럼의 결측치를 '기타'로 채움
# _1순위여유업종 컬럼의 결측치를 '기타'로 채움
# _2순위여유업종 컬럼의 결측치를 '기타'로 채움
# _3순위여유업종 컬럼의 결측치를 '기타'로 채움
# _1순위납부업종 컬럼의 결측치를 '기타'로 채움
# _2순위납부업종 컬럼의 결측치를 '기타'로 채움
# _3순위납부업종 컬럼의 결측치를 '기타'로 채움
# 최종카드론_신청경로코드 컬럼의 결측치를 '기타'로 채움

# %%
# Out:
#    기준년월  ID  최종이용일자_기본  최종이용일자_신판  최종이용일자_CA  최종이용일자_카드론  최종이용일자_체크  \
# 0     0   0   20180719   20180713   20180719       10101   20180203
# 1     0   1   20180719   20180719   20170728    20170327      10101
# 2     0   2   20180706   20180706   20180706    20151119   20141230
# 3     0   3   20180721   20180715   20180721       10101   20141111
# 4     0   4   20180124   20180124      10101       10101   20180512
#
#    최종이용일자_일시불  최종이용일자_할부  이용건수_신용_B0M  ...  신청건수_ATM_CL_R6M  승인거절건수_B0M  \
# 0    20180709   20180713           11  ...                0           0
# 1    20180719   20171231           13  ...                0           0
# 2    20180706   20180627           12  ...                0           0
# 3    20180704   20180715            6  ...                0           0
# 4    20180124      10101           -2  ...                0           0
#
#    승인거절건수_한도초과_B0M  승인거절건수_BL_B0M  승인거절건수_R3M  승인거절건수_한도초과_R3M  승인거절건수_BL_R3M  \
# ...

# %%
# 날짜(YYYYMMDD) 또는 '사용하지 않음'(예: 10101) 패턴을 가진 int 컬럼 자동 탐지 및 전처리

def is_date_or_unused_col(series):
    # int 타입, 값이 100000 이하(사용안함) 또는 8자리(YYYYMMDD)인 값이 많으면 True
    if not np.issubdtype(series.dtype, np.integer):
        return False
    vals = series.dropna().unique()
    # 8자리(YYYYMMDD)와 100000 이하 값이 전체의 90% 이상이면 해당 패턴으로 간주
    date_like = sum((v > 10000000) & (v < 30000000) for v in vals)
    unused_like = sum(v == 10101 for v in vals)
    ratio = (date_like + unused_like) / len(vals) if len(vals) > 0 else 0
    return ratio > 0.9

for col in df.columns:
    if is_date_or_unused_col(df[col]):
        def parse_date_or_unused(x):
            if x == 10101:
                return np.nan
            try:
                return pd.to_datetime(str(int(x)), format='%Y%m%d')
            except:
                return np.nan
        df[col] = df[col].apply(parse_date_or_unused)
        print(f"{col} 컬럼을 날짜/10101(NaT) 패턴으로 자동 전처리")
# Out:
# 최종이용일자_기본 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_신판 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_CA 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_카드론 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_체크 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_일시불 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리
# 최종이용일자_할부 컬럼을 날짜/10101(NaN) 패턴으로 자동 전처리

# %%
# '최종카드론_금융상환방식코드' 컬럼의 결측치를 최빈값으로 채우기
df['최종카드론_금융상환방식코드'] = df['최종카드론_금융상환방식코드'].fillna(df['최종카드론_금융상환방식코드'].mode()[0])

# %%
df['최종카드론_금융상환방식코드'] = df['최종카드론_금융상환방식코드'].astype('object')
print(df['최종카드론_금융상환방식코드'].dtype)
# Out:
# object

# %%
df['최종이용일자_기본'].head()
# Out:
# 0   2018-07-19
# 1   2018-07-19
# 2   2018-07-06
# 3   2018-07-21
# 4   2018-01-24
# Name: 최종이용일자_기본, dtype: datetime64[ns]

# %%
df['최종카드론_대출일자'] = pd.to_datetime(df['최종카드론_대출일자'], format='%Y%m%d', errors='coerce')

# %%
#결측치 앞뒤날짜기준으로
df['최종카드론_대출일자'] = df['최종카드론_대출일자'].fillna(method='ffill').fillna(method='bfill')
# Out:
# C:\Users\rtc32\AppData\Local\Temp\ipykernel_17636\3955546613.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['최종카드론_대출일자'] = df['최종카드론_대출일자'].fillna(method='ffill').fillna(method='bfill')

# %%
#상관계수가 1인 컬럼제거 할부건수_부분_12MR12M <-> 이용건수부분무이자_R12M : 1.0

df = df.drop(columns=['이용건수_부분무이자_R12M'])

# %%
for col in df.columns:
    print(f"컬럼명: {col}")
    print(f" - 데이터 타입: {df[col].dtype}")
    print(f" - 고유값(최대 10개): {df[col].unique()[:10]}")
    print("-" * 40)
# Out:
# 컬럼명: 기준년월
#  - 데이터 타입: int32
#  - 고유값(최대 10개): [201807 201808 201809 201810 201811 201812]
# ----------------------------------------
# 컬럼명: ID
#  - 데이터 타입: object
#  - 고유값(최대 10개): ['TRAIN_000000' 'TRAIN_000001' 'TRAIN_000002' 'TRAIN_000003'
#  'TRAIN_000004' 'TRAIN_000005' 'TRAIN_000006' 'TRAIN_000007'
#  'TRAIN_000008' 'TRAIN_000009']
# ----------------------------------------
# 컬럼명: 최종이용일자_기본
#  - 데이터 타입: datetime64[ns]
#  - 고유값(최대 10개): <DatetimeArray>
# ['2018-07-19 00:00:00', '2018-07-06 00:00:00', '2018-07-21 00:00:00',
#  '2018-01-24 00:00:00', '2016-04-25 00:00:00', '2018-07-31 00:00:00',
#  '2018-07-26 00:00:00', '2018-07-10 00:00:00',                 'NaT',
#  '2018-06-05 00:00:00']
# Length: 10, dtype: datetime64[ns]
# ----------------------------------------
# 컬럼명: 최종이용일자_신판
#  - 데이터 타입: datetime64[ns]
#  - 고유값(최대 10개): <DatetimeArray>
# ['2018-07-13 00:00:00', '2018-07-19 00:00:00', '2018-07-06 00:00:00',
# ...

# %%
df.to_parquet("3.승인매출정보_전처리완.parquet")
